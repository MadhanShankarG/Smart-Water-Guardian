# %%
# !pip install numpy pandas scikit-learn tensorflow joblib
# Out:
# Requirement already satisfied: numpy in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (2.4.2)
# Requirement already satisfied: pandas in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (3.0.0)
# Requirement already satisfied: scikit-learn in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: tensorflow in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: joblib in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (14.3.2)
# Requirement already satisfied: namex in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.1)
# Requirement already satisfied: pillow in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/madhang/Downloads/water_quality_project/waterenv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import joblib
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("pond_dataset.csv")

print(df.head())
print(df.columns)
# Out:
#        id     created_date  water_pH  TDS  water_temp
# 0  181740  1/26/2023 10:38      7.94  329       23.69
# 1  181741  1/26/2023 10:38      7.79  329       23.69
# 2  181747  1/26/2023 10:39      5.98  233       23.75
# 3  181748  1/26/2023 10:39      7.32  233       23.75
# 4  181754  1/26/2023 10:39      7.90  233       23.75
# Index(['id', 'created_date', 'water_pH', 'TDS', 'water_temp'], dtype='str')

# %%
# normalize column names
df.columns = df.columns.str.lower()

# rename for simplicity
df = df.rename(columns={
    "water_ph": "ph",
    "tds": "tds",
    "water_temp": "temp"
})

# %%
df["created_date"] = pd.to_datetime(df["created_date"])
df = df.sort_values("created_date")

# =========================
# features
# =========================
X = df[["ph", "tds", "temp"]].values

# =========================
# create labels (safe/unsafe)
# =========================
def create_label(row):
    if 6.5 <= row[0] <= 8.5 and row[1] <= 500 and 24 <= row[2] <= 27:
        return 1
    return 0

y = np.array([create_label(r) for r in X])

print("Safe:", sum(y))
print("Unsafe:", len(y)-sum(y))
# Out:
# Safe: 118286
# Unsafe: 387444

# %%
# ================================
# IMPORTS
# ================================
import numpy as np
import pandas as pd
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout


# ================================
# LOAD DATASET
# ================================
df = pd.read_csv("pond_dataset.csv")


# ================================
# SELECT FEATURES
# (based on your dataset columns)
# ================================
X = df[["water_pH", "TDS", "water_temp"]].values


# ================================
# CREATE LABELS (rule based)
# ================================
def create_label(row):
    if (
        6.5 <= row[0] <= 8.5 and
        row[1] <= 500 and
        24 <= row[2] <= 27
    ):
        return 1
    return 0

y = np.array([create_label(r) for r in X])


# ================================
# CLEANING
# ================================
imputer = SimpleImputer()
scaler = StandardScaler()

X = imputer.fit_transform(X)
X = scaler.fit_transform(X)


# ================================
# CREATE SEQUENCES
# ================================
WINDOW = 20

X_seq = []
y_seq = []

for i in range(len(X) - WINDOW):
    X_seq.append(X[i:i+WINDOW])
    y_seq.append(y[i+WINDOW])

X_seq = np.array(X_seq)
y_seq = np.array(y_seq)

print("Shape:", X_seq.shape)


# ================================
# SPLIT (STRATIFIED)
# ================================
X_train, X_test, y_train, y_test = train_test_split(
    X_seq,
    y_seq,
    test_size=0.2,
    stratify=y_seq,
    shuffle=True,
    random_state=42
)


# ================================
# CLASS WEIGHTS
# ================================
weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train),
    y=y_train
)

class_weights = {0: weights[0], 1: weights[1]}
print("Class weights:", class_weights)


# ================================
# CNN + LSTM MODEL
# ================================
model = Sequential([
    Input(shape=(WINDOW, 3)),

    Conv1D(32, kernel_size=3, activation="relu"),
    MaxPooling1D(2),

    LSTM(32),

    Dropout(0.3),

    Dense(16, activation="relu"),
    Dense(1, activation="sigmoid")
])


model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()


# ================================
# TRAIN
# ================================
model.fit(
    X_train,
    y_train,
    epochs=15,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weights
)


# ================================
# EVALUATE
# ================================
loss, acc = model.evaluate(X_test, y_test)
print("Test accuracy:", acc)


# ================================
# SAVE
# ================================
model.save("pond_cnn_lstm_model.keras")

joblib.dump(scaler, "pond_scaler.pkl")
joblib.dump(imputer, "pond_imputer.pkl")
# Out:
# Shape: (505710, 20, 3)
# Class weights: {0: np.float64(0.6526448240816919), 1: np.float64(2.137788909673124)}
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)               │ (None, 18, 32)         │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 9, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,185 (35.88 KB)
#  Trainable params: 9,185 (35.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8163 - loss: 0.3094 - val_accuracy: 0.8177 - val_loss: 0.3372
# Epoch 2/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8209 - loss: 0.2941 - val_accuracy: 0.8335 - val_loss: 0.3135
# Epoch 3/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8219 - loss: 0.2923 - val_accuracy: 0.8190 - val_loss: 0.3162
# Epoch 4/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8229 - loss: 0.2910 - val_accuracy: 0.8293 - val_loss: 0.3171
# Epoch 5/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8238 - loss: 0.2899 - val_accuracy: 0.8097 - val_loss: 0.3364
# Epoch 6/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8247 - loss: 0.2892 - val_accuracy: 0.8274 - val_loss: 0.3235
# Epoch 7/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8255 - loss: 0.2884 - val_accuracy: 0.8261 - val_loss: 0.3224
# Epoch 8/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8255 - loss: 0.2878 - val_accuracy: 0.8312 - val_loss: 0.3167
# Epoch 9/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8261 - loss: 0.2873 - val_accuracy: 0.8266 - val_loss: 0.3162
# Epoch 10/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8260 - loss: 0.2871 - val_accuracy: 0.8201 - val_loss: 0.3233
# Epoch 11/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8259 - loss: 0.2865 - val_accuracy: 0.8257 - val_loss: 0.3151
# Epoch 12/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8261 - loss: 0.2863 - val_accuracy: 0.8236 - val_loss: 0.3229
# Epoch 13/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8260 - loss: 0.2861 - val_accuracy: 0.8267 - val_loss: 0.3191
# Epoch 14/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8263 - loss: 0.2859 - val_accuracy: 0.8306 - val_loss: 0.3149
# Epoch 15/15
# 2529/2529 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8264 - loss: 0.2857 - val_accuracy: 0.8204 - val_loss: 0.3285
# 3161/3161 ━━━━━━━━━━━━━━━━━━━━ 1s 444us/step - accuracy: 0.8213 - loss: 0.3283
# Test accuracy: 0.8212611675262451
# ['pond_imputer.pkl']

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

y_pred = (model.predict(X_test) > 0.5).astype(int)

print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# 3161/3161 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step
# Confusion Matrix
# [[59861 17625]
#  [  453 23203]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.77      0.87     77486
#            1       0.57      0.98      0.72     23656
#
#     accuracy                           0.82    101142
#    macro avg       0.78      0.88      0.79    101142
# weighted avg       0.89      0.82      0.83    101142
